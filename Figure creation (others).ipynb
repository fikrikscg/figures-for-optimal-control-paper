# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
fig1 = 13
fig2 = 7
fs = 18
dpi_qual = 600
linew = 2.5
bar_width = 0.35

# %% [markdown]
# # Without fractional milling

# %% [markdown]
# ## Average feeding and variability

# %% [markdown]
# ### BFFPC

# %%
name_bffpc = ['R. s. 1', 'R. s. 2', 'R. s. 3', 'R. s. 4', 'R. s. 5', 'R. s. 6']

# %%
afeeding_bffpc_without = [2.663060292, 2.663060292, 2.663060292, 2.663060292, 2.663060292, 2.663060292]
vfeeding_bffpc_without = [0.420836573, 0.54628414, 0.561046513, 0.554770264, 0.409229398, 0.557077863]

plt.figure(figsize = (fig1, fig2))
N = len(afeeding_bffpc_without)
ind = np.arange(N)
plt.ylim(0, 4.2)
plt.bar(ind, afeeding_bffpc_without, bar_width, color = 'g', label = 'Av. Feed.')
# plt.bar(ind + width, cap_without_fix_str, width, color = 'y', label = 'Storage Bin Max. Inv.')     
plt.legend(frameon = False, fontsize = fs)
plt.ylabel("Dry tons", fontsize = fs)
plt.tick_params(axis = 'y', labelsize = fs)
plt.tick_params(axis = 'x', labelsize = fs)

axes2 = plt.twinx()
axes2.plot(name_bffpc, vfeeding_bffpc_without, color = 'k', label = 'Coef. Var.', linewidth = linew)
axes2.set_ylim(0, 2)
axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
axes2.set_ylabel('Coef. Var.', fontsize = fs)
axes2.tick_params(axis = "y", labelsize = fs)

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v5/Figures/feeding_bffpc_without.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# fig, ax1 = plt.subplots(figsize = (fig1, fig2))
# color_bar = 'olivedrab'
# # ax1.set_title('Average Percipitation Percentage by Month', fontsize = fs)
# # ax1.set_xlabel('Month', fontsize = fs)
# ax1.set_ylabel('Av. Feed. (Dry tons/hr)', fontsize = fs, color = color_bar)
# ax2 = sns.barplot(x = name_bffpc, y = afeeding_bffpc_without, color = color_bar)
# ax2.set_ylim([0,3.72])
# ax1.tick_params(axis = 'y')
# ax2 = ax1.twinx()
# color_line = 'purple'
# ax2.set_ylabel('Coef. Var.', fontsize = fs, color = color_line)
# ax2 = sns.lineplot(x = name_bffpc, y = vfeeding_bffpc_without, sort = False, color = color_line, linewidth = linew)
# ax2.set_ylim([0,1.8])
# ax2.tick_params(axis = 'y', color = color_line)
# fig.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v2/Figures/feeding_bffpc_without.jpg', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ### HPC

# %%
name_hpc = ['40H,60L,100M', '40H,100M,60L', '60L,100M,40H', '6L,10M,4H X10', '100M,60L,40H']

# %%
afeeding_hpc_without = [2.737518254, 2.703741589, 2.737518254, 2.675446619, 2.737518254]
vfeeding_hpc_without = [0.309860704, 0.397174352, 0.139822044, 5.87E-16, 0.129116005]

plt.figure(figsize = (fig1, fig2))
N = len(afeeding_hpc_without)
ind = np.arange(N)
plt.ylim(0, 4.2)
plt.bar(ind, afeeding_hpc_without, bar_width, color = 'g', label = 'Av. Feed.')
# plt.bar(ind + width, cap_without_fix_str, width, color = 'y', label = 'Storage Bin Max. Inv.')     
plt.legend(frameon = False, fontsize = fs)
plt.ylabel("Dry tons", fontsize = fs)
plt.tick_params(axis = 'y', labelsize = fs)
plt.tick_params(axis = 'x', labelsize = fs)

axes2 = plt.twinx()
axes2.plot(name_hpc, vfeeding_hpc_without, color = 'k', label = 'Coef. Var.', linewidth = linew)
axes2.set_ylim(0, 2)
axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
axes2.set_ylabel('Coef. Var.', fontsize = fs)
axes2.tick_params(axis = "y", labelsize = fs)

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v5/Figures/feeding_hpc_without.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# fig, ax1 = plt.subplots(figsize = (fig1, fig2))
# color_bar = 'olivedrab'
# ax1.set_ylabel('Av. Feed. (Dry tons/hr)', fontsize = fs, color = color_bar)
# ax2 = sns.barplot(x = name_hpc, y = afeeding_hpc_without, color = color_bar)
# ax2.set_ylim([0,3.72])
# ax1.tick_params(axis = 'y')
# ax2 = ax1.twinx()
# color_line = 'purple'
# ax2.set_ylabel('Coef. Var.', fontsize = fs, color = color_line)
# ax2 = sns.lineplot(x = name_hpc, y = vfeeding_hpc_without, sort = False, color = color_line, linewidth = linew)
# ax2.set_ylim([0,1.8])
# ax2.tick_params(axis = 'y', color = color_line)
# fig.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v2/Figures/feeding_hpc_without.jpg', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Capacity analysis

# %% [markdown]
# ### Fixed capacity

# %%
cap_without_fix_met = [3.093374767, 0, 3.093374767, 0.182682524, 3.093374767]
cap_without_fix_str = [4.535925, 0, 4.535925, 1.750676772, 4.535925]
cap_bins = [4.535, 4.535, 4.535, 4.535, 4.535]

plt.figure(figsize = (fig1, fig2))          
N = len(cap_without_fix_met)  
ind = np.arange(N)
plt.ylim(0, 13)
plt.bar(ind, cap_without_fix_met, bar_width, color = 'r', label = 'Metering Bin Max. Inv.')
plt.bar(ind + bar_width, cap_without_fix_str, bar_width, color = 'y', label = 'Storage Bin Max. Inv.')     
plt.legend(frameon = False, fontsize = fs)
plt.ylabel("Dry tons", fontsize = fs)
plt.tick_params(axis = 'y', labelsize = fs)
plt.tick_params(axis = 'x', labelsize = fs)

axes2 = plt.twinx()
axes2.plot(name_hpc, cap_bins, color = 'k', label = 'Capacity', linewidth = linew)
axes2.set_ylim(0, 13)
axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
axes2.tick_params(axis = "y", labelsize = fs)
# axes2.set_ylabel('Line plot')

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v5/Figures/inventory_fixed_without.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ### Flexible capacity

# %%
cap_without_flex_met = [3.093374767, 0, 3.093374767, 0.182682524, 3.093374767]
cap_without_flex_str = [4.535925, 0, 4.535925, 1.404302572, 4.535925]
cap_bins = [4.535, 4.535, 4.535, 4.535, 4.535]
cap_bins_new = [9.07185, 9.07185, 9.07185, 9.07185, 9.07185]

plt.figure(figsize = (fig1, fig2))          
N = len(cap_without_fix_met)  
ind = np.arange(N)
plt.ylim(0, 13)
plt.bar(ind, cap_without_flex_met, bar_width, color = 'r', label = 'Metering Bin Max. Inv.')
plt.bar(ind + bar_width, cap_without_flex_str, bar_width, color = 'y', label = 'Storage Bin Max. Inv.')     
plt.legend(frameon = False, fontsize = fs)
plt.ylabel("Dry tons", fontsize = fs)
plt.tick_params(axis = 'y', labelsize = fs)
plt.tick_params(axis = 'x', labelsize = fs)

axes2 = plt.twinx()
axes2.plot(name_hpc, cap_bins, color = 'k', label = 'Old Capacity', linewidth = linew)
axes2.plot(name_hpc, cap_bins_new, color = 'green', label = 'New Capacity', linewidth = linew)
axes2.set_ylim(0, 13)
axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
axes2.tick_params(axis = "y", labelsize = fs)
# axes2.set_ylabel('Line plot')

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v5/Figures/inventory_flexible_without.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# # With fractional milling

# %% [markdown]
# ## Average feeding and variability

# %% [markdown]
# ### BFFPC

# %%
afeeding_bffpc_with = [3.431776974, 3.515478851, 3.603365823, 3.431776974, 3.515478851, 3.603365823]
vfeeding_bffpc_with = [0.332872567, 1.18805756, 1.164095954, 0.301415906, 1.694823998, 1.144432058]

plt.figure(figsize = (fig1, fig2))
N = len(afeeding_bffpc_with)
ind = np.arange(N)
plt.ylim(0, 4.2)
plt.bar(ind, afeeding_bffpc_with, bar_width, color = 'g', label = 'Av. Feed.')
# plt.bar(ind + width, cap_without_fix_str, width, color = 'y', label = 'Storage Bin Max. Inv.')     
plt.legend(frameon = False, fontsize = fs)
plt.ylabel("Dry tons", fontsize = fs)
plt.tick_params(axis = 'y', labelsize = fs)
plt.tick_params(axis = 'x', labelsize = fs)

axes2 = plt.twinx()
axes2.plot(name_bffpc, vfeeding_bffpc_with, color = 'k', label = 'Coef. Var.', linewidth = linew)
axes2.set_ylim(0, 2)
axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
axes2.set_ylabel('Coef. Var.', fontsize = fs)
axes2.tick_params(axis = "y", labelsize = fs)

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v5/Figures/feeding_bffpc.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# fig, ax1 = plt.subplots(figsize = (fig1, fig2))
# color_bar = 'olivedrab'
# ax1.set_ylabel('Av. Feed. (Dry tons/hr)', fontsize = fs, color = color_bar)
# ax2 = sns.barplot(x = name_bffpc, y = afeeding_bffpc_with, color = color_bar)
# ax2.set_ylim([0,3.72])
# ax1.tick_params(axis = 'y')
# ax2 = ax1.twinx()
# color_line = 'purple'
# ax2.set_ylabel('Coef. Var.', fontsize = fs, color = color_line)
# ax2 = sns.lineplot(x = name_bffpc, y = vfeeding_bffpc_with, sort = False, color = color_line, linewidth = linew)
# ax2.set_ylim([0,1.8])
# ax2.tick_params(axis = 'y', color = color_line)
# fig.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v2/Figures/feeding_bffpc.jpg', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ### HPC

# %%
afeeding_hpc_with = [3.478362182, 3.478362182, 3.553396189, 3.689846602, 3.628881395]
vfeeding_hpc_with = [0.262808222, 0.281524836, 0.093253727, 1.92E-15, 6.25E-16]

plt.figure(figsize = (fig1, fig2))
N = len(afeeding_hpc_with)
ind = np.arange(N)
plt.ylim(0, 4.2)
plt.bar(ind, afeeding_hpc_with, bar_width, color = 'g', label = 'Av. Feed.')
# plt.bar(ind + width, cap_without_fix_str, width, color = 'y', label = 'Storage Bin Max. Inv.')     
plt.legend(frameon = False, fontsize = fs)
plt.ylabel("Dry tons", fontsize = fs)
plt.tick_params(axis = 'y', labelsize = fs)
plt.tick_params(axis = 'x', labelsize = fs)

axes2 = plt.twinx()
axes2.plot(name_hpc, vfeeding_hpc_with, color = 'k', label = 'Coef. Var.', linewidth = linew)
axes2.set_ylim(0, 2)
axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
axes2.set_ylabel('Coef. Var.', fontsize = fs)
axes2.tick_params(axis = "y", labelsize = fs)

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v5/Figures/feeding_hpc.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# fig, ax1 = plt.subplots(figsize = (fig1, fig2))
# color_bar = 'olivedrab'
# ax1.set_ylabel('Av. Feed. (Dry tons/hr)', fontsize = fs, color = color_bar)
# ax2 = sns.barplot(x = name_hpc, y = afeeding_hpc_with, color = color_bar)
# ax2.set_ylim([0,3.72])
# ax1.tick_params(axis = 'y')
# ax2 = ax1.twinx()
# color_line = 'purple'
# ax2.set_ylabel('Coef. Var.', fontsize = fs, color = color_line)
# ax2 = sns.lineplot(x = name_hpc, y = vfeeding_hpc_with, sort = False, color = color_line, linewidth = linew)
# ax2.set_ylim([0,1.8])
# ax2.tick_params(axis = 'y', color = color_line)
# fig.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v2/Figures/feeding_hpc.jpg', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Capacity analysis

# %% [markdown]
# ### Fixed capacity

# %%
cap_with_fix_met = [0.000183763, 0.205970498, 2.07372048, 0.718034664, 2.042090816]
cap_with_fix_str = [3.136710462, 0.107160327, 4.535925, 0.997426375, 4.535925]
cap_bins = [4.535, 4.535, 4.535, 4.535, 4.535]

plt.figure(figsize = (fig1, fig2))       
N = len(cap_with_fix_met)
ind = np.arange(N)
plt.ylim(0, 13)
plt.bar(ind, cap_with_fix_met, bar_width, color = 'r', label = 'Metering Bin Max. Inv.')
plt.bar(ind + bar_width, cap_with_fix_str, bar_width, color = 'y', label = 'Storage Bin Max. Inv.')     
plt.legend(frameon = False, fontsize = fs)
plt.ylabel("Dry tons", fontsize = fs)
plt.tick_params(axis = 'y', labelsize = fs)
plt.tick_params(axis = 'x', labelsize = fs)

axes2 = plt.twinx()
axes2.plot(name_hpc, cap_bins, color = 'k', label = 'Capacity', linewidth = linew)
axes2.set_ylim(0, 13)
axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
axes2.tick_params(axis = "y", labelsize = fs)
# axes2.set_ylabel('Line plot')

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v5/Figures/inventory_fixed.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ### Flexible capacity

# %%
cap_with_flex_met = [0.000367526, 0.205970498, 2.079538338, 0.646167276, 3.417377119]
cap_with_flex_str = [3.136894225, 0.105768634, 4.535925, 0.685037788, 7.130783743]
cap_bins = [4.535, 4.535, 4.535, 4.535, 4.535]
cap_bins_new = [9.07185, 9.07185, 9.07185, 9.07185, 9.07185]

plt.figure(figsize = (fig1, fig2))          
N = len(cap_with_flex_met)  
ind = np.arange(N)
plt.ylim(0, 13)
plt.bar(ind, cap_with_flex_met, bar_width, color = 'r', label = 'Metering Bin Max. Inv.')
plt.bar(ind + bar_width, cap_with_flex_str, bar_width, color = 'y', label = 'Storage Bin Max. Inv.')     
plt.legend(frameon = False, fontsize = fs)
plt.ylabel("Dry tons", fontsize = fs)
plt.tick_params(axis = 'y', labelsize = fs)
plt.tick_params(axis = 'x', labelsize = fs)

axes2 = plt.twinx()
axes2.plot(name_hpc, cap_bins, color = 'k', label = 'Old Capacity', linewidth = linew)
axes2.plot(name_hpc, cap_bins_new, color = 'green', label = 'New Capacity', linewidth = linew)
axes2.set_ylim(0, 13)
axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
axes2.tick_params(axis = "y", labelsize = fs)
# axes2.set_ylabel('Line plot')

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v5/Figures/inventory_flexible.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

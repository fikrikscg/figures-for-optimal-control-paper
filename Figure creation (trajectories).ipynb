# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functools import reduce

# %% [markdown]
# # Variables

# %%
fs = 15
dpi_qual = 600
linew = 2.5
fig1 = 20
fig2 = 12

# %% [markdown]
# # Templates

# %%
fig, ax = plt.subplots(1, 1, figsize = (18,6))
ax.plot(new_merged_data['VG Infeed Current_x'])
ax.set_xlabel("Time", fontsize = fs)
ax.set_ylabel("Amp", fontsize = fs)
ax.legend(["No DG", "DG at center 1", "DG at center 3"], fontsize  = fs, frameon = False)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v2/Figures', dpi = dpi_qual)
# ax.axvline(x = f1s, ymin = 0.5, ymax = 0.75, color = 'red')
# ax.set_title("Current of DC-5 (Red lines show stoppage times in Vermeer grinder)", fontsize = 14)
# ax.plot(vol, nodg, linestyle = '-', marker = "o")
# fig.savefig('Fig6a.jpg', dpi = 900)
# fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize = (18, 18))
# ax1.legend(['NSGA-II', 'Hybrid-NSGA-II'], fontsize = 13, frameon = False, loc = 'upper left')
# ax1.set_xticks([]) # To remove x ticks

# %% [markdown]
# # Without

# %% [markdown]
# ## Infeed trajectory

# %%
without_trajectory_infeed = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper\Without.xlsx', 
    sheet_name = 'Infeed')

fig, ([ax1, ax2], [ax3, ax4]) = plt.subplots(2, 2, figsize = (fig1, fig2))
ax1.plot(without_trajectory_infeed["Time"], without_trajectory_infeed["BFFPC - Random sequence 1"], 
         linewidth = linew, color = "r")
ax1.plot(without_trajectory_infeed["Time"], without_trajectory_infeed["HPC - 40H,60L,100M"], 
         linewidth = linew, color = "b")
ax1.set_xlabel("Time (minutes)", fontsize = fs)
ax1.set_ylabel("Dry tons/hr", fontsize = fs)
ax1.set_ylim([0, 6.35])
ax1.legend(["BFFPC - Random sequence 1", "HPC - 40H,60L,100M"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax1.tick_params(axis = "x", labelsize = fs)
ax1.tick_params(axis = "y", labelsize = fs)
ax2.plot(without_trajectory_infeed["Time"], without_trajectory_infeed["BFFPC - Random sequence 2"], 
         linewidth = linew, color = "r")
ax2.plot(without_trajectory_infeed["Time"], without_trajectory_infeed["HPC - 60L,100M,40H"], 
         linewidth = linew, color = "b")
ax2.set_xlabel("Time (minutes)", fontsize = fs)
ax2.set_ylabel("Dry tons/hr", fontsize = fs)
ax2.set_ylim([0, 6.35])
ax2.legend(["BFFPC - Random sequence 2", "HPC - 60L,100M,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax2.tick_params(axis = "x", labelsize = fs)
ax2.tick_params(axis = "y", labelsize = fs)
ax3.plot(without_trajectory_infeed["Time"], without_trajectory_infeed["BFFPC - Random sequence 3"], 
         linewidth = linew, color = "r")
ax3.plot(without_trajectory_infeed["Time"], without_trajectory_infeed["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "b")
ax3.set_xlabel("Time (minutes)", fontsize = fs)
ax3.set_ylabel("Dry tons/hr", fontsize = fs)
ax3.set_ylim([0, 6.35])
ax3.legend(["BFFPC - Random sequence 3", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax3.tick_params(axis = "x", labelsize = fs)
ax3.tick_params(axis = "y", labelsize = fs)
ax4.plot(without_trajectory_infeed["Time"], without_trajectory_infeed["BFFPC - Random sequence 4"], 
         linewidth = linew, color = "r")
ax4.plot(without_trajectory_infeed["Time"], without_trajectory_infeed["HPC - 100M,60L,40H"], 
         linewidth = linew, color = "b")
ax4.set_xlabel("Time (minutes)", fontsize = fs)
ax4.set_ylabel("Dry tons/hr", fontsize = fs)
ax4.set_ylim([0, 6.35])
ax4.legend(["BFFPC - Random sequence 4", "HPC - 100M,60L,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax4.tick_params(axis = "x", labelsize = fs)
ax4.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v5/Figures/infeed_without.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Reactor trajectory

# %%
without_trajectory_reactor = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper\Without.xlsx', 
    sheet_name = 'Feeding')

fig, ([ax1, ax2], [ax3, ax4]) = plt.subplots(2, 2, figsize = (fig1, fig2))
ax1.plot(without_trajectory_reactor["Time"], without_trajectory_reactor["BFFPC - Random sequence 1"], 
         linewidth = linew, color = "r")
ax1.plot(without_trajectory_reactor["Time"], without_trajectory_reactor["HPC - 40H,60L,100M"], 
         linewidth = linew, color = "b")
ax1.set_xlabel("Time (minutes)", fontsize = fs)
ax1.set_ylabel("Dry tons/hr", fontsize = fs)
ax1.set_ylim([0, 16])
ax1.legend(["BFFPC - Random sequence 1", "HPC - 40H,60L,100M"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax1.tick_params(axis = "x", labelsize = fs)
ax1.tick_params(axis = "y", labelsize = fs)
ax2.plot(without_trajectory_reactor["Time"], without_trajectory_reactor["BFFPC - Random sequence 2"], 
         linewidth = linew, color = "r")
ax2.plot(without_trajectory_reactor["Time"], without_trajectory_reactor["HPC - 60L,100M,40H"], 
         linewidth = linew, color = "b")
ax2.set_xlabel("Time (minutes)", fontsize = fs)
ax2.set_ylabel("Dry tons/hr", fontsize = fs)
ax2.set_ylim([0, 16])
ax2.legend(["BFFPC - Random sequence 2", "HPC - 60L,100M,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax2.tick_params(axis = "x", labelsize = fs)
ax2.tick_params(axis = "y", labelsize = fs)
ax3.plot(without_trajectory_reactor["Time"], without_trajectory_reactor["BFFPC - Random sequence 3"], 
         linewidth = linew, color = "r")
ax3.plot(without_trajectory_reactor["Time"], without_trajectory_reactor["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "b")
ax3.set_xlabel("Time (minutes)", fontsize = fs)
ax3.set_ylabel("Dry tons/hr", fontsize = fs)
ax3.set_ylim([0, 16])
ax3.legend(["BFFPC - Random sequence 3", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax3.tick_params(axis = "x", labelsize = fs)
ax3.tick_params(axis = "y", labelsize = fs)
ax4.plot(without_trajectory_reactor["Time"], without_trajectory_reactor["BFFPC - Random sequence 4"], 
         linewidth = linew, color = "r")
ax4.plot(without_trajectory_reactor["Time"], without_trajectory_reactor["HPC - 100M,60L,40H"], 
         linewidth = linew, color = "b")
ax4.set_xlabel("Time (minutes)", fontsize = fs)
ax4.set_ylabel("Dry tons/hr", fontsize = fs)
ax4.set_ylim([0, 16])
ax4.legend(["BFFPC - Random sequence 4", "HPC - 100M,60L,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax4.tick_params(axis = "x", labelsize = fs)
ax4.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v5/Figures/reactor_without.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Inventory trajectory

# %%
without_trajectory_inventory = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper\Without.xlsx', 
    sheet_name = 'Inventory')

fig, ([ax1, ax2], [ax3, ax4]) = plt.subplots(2, 2, figsize = (fig1, fig2))
ax1.plot(without_trajectory_inventory["Time"], without_trajectory_inventory["BFFPC - Random sequence 1"], 
         linewidth = linew, color = "r")
ax1.plot(without_trajectory_inventory["Time"], without_trajectory_inventory["HPC - 40H,60L,100M"], 
         linewidth = linew, color = "b")
ax1.set_xlabel("Time (minutes)", fontsize = fs)
ax1.set_ylabel("Dry tons", fontsize = fs)
ax1.set_ylim([0, 12])
ax1.legend(["BFFPC - Random sequence 1", "HPC - 40H,60L,100M"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax1.tick_params(axis = "x", labelsize = fs)
ax1.tick_params(axis = "y", labelsize = fs)
ax2.plot(without_trajectory_inventory["Time"], without_trajectory_inventory["BFFPC - Random sequence 2"], 
         linewidth = linew, color = "r")
ax2.plot(without_trajectory_inventory["Time"], without_trajectory_inventory["HPC - 60L,100M,40H"], 
         linewidth = linew, color = "b")
ax2.set_xlabel("Time (minutes)", fontsize = fs)
ax2.set_ylabel("Dry tons", fontsize = fs)
ax2.set_ylim([0, 12])
ax2.legend(["BFFPC - Random sequence 2", "HPC - 60L,100M,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax2.tick_params(axis = "x", labelsize = fs)
ax2.tick_params(axis = "y", labelsize = fs)
ax3.plot(without_trajectory_inventory["Time"], without_trajectory_inventory["BFFPC - Random sequence 3"], 
         linewidth = linew, color = "r")
ax3.plot(without_trajectory_inventory["Time"], without_trajectory_inventory["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "b")
ax3.set_xlabel("Time (minutes)", fontsize = fs)
ax3.set_ylabel("Dry tons", fontsize = fs)
ax3.set_ylim([0, 12])
ax3.legend(["BFFPC - Random sequence 3", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax3.tick_params(axis = "x", labelsize = fs)
ax3.tick_params(axis = "y", labelsize = fs)
ax4.plot(without_trajectory_inventory["Time"], without_trajectory_inventory["BFFPC - Random sequence 4"], 
         linewidth = linew, color = "r")
ax4.plot(without_trajectory_inventory["Time"], without_trajectory_inventory["HPC - 100M,60L,40H"], 
         linewidth = linew, color = "b")
ax4.set_xlabel("Time (minutes)", fontsize = fs)
ax4.set_ylabel("Dry tons", fontsize = fs)
ax4.set_ylim([0, 12])
ax4.legend(["BFFPC - Random sequence 4", "HPC - 100M,60L,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax4.tick_params(axis = "x", labelsize = fs)
ax4.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v5/Figures/inventory_without.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# # With

# %% [markdown]
# ## Infeed trajectory

# %%
with_trajectory_infeed = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper\With.xlsx', 
    sheet_name = 'Infeed')

fig, ([ax1, ax2], [ax3, ax4]) = plt.subplots(2, 2, figsize = (fig1, fig2))
ax1.plot(with_trajectory_infeed["Time"], with_trajectory_infeed["BFFPC - Random sequence 1"], 
         linewidth = linew, color = "r")
ax1.plot(with_trajectory_infeed["Time"], with_trajectory_infeed["HPC - 40H,60L,100M"], 
         linewidth = linew, color = "b")
ax1.set_xlabel("Time (minutes)", fontsize = fs)
ax1.set_ylabel("Dry tons/hr", fontsize = fs)
ax1.set_ylim([0, 6.35])
ax1.legend(["BFFPC - Random sequence 1", "HPC - 40H,60L,100M"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax1.tick_params(axis = "x", labelsize = fs)
ax1.tick_params(axis = "y", labelsize = fs)
ax2.plot(with_trajectory_infeed["Time"], with_trajectory_infeed["BFFPC - Random sequence 2"], 
         linewidth = linew, color = "r")
ax2.plot(with_trajectory_infeed["Time"], with_trajectory_infeed["HPC - 60L,100M,40H"], 
         linewidth = linew, color = "b")
ax2.set_xlabel("Time (minutes)", fontsize = fs)
ax2.set_ylabel("Dry tons/hr", fontsize = fs)
ax2.set_ylim([0, 6.35])
ax2.legend(["BFFPC - Random sequence 2", "HPC - 60L,100M,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax2.tick_params(axis = "x", labelsize = fs)
ax2.tick_params(axis = "y", labelsize = fs)
ax3.plot(with_trajectory_infeed["Time"], with_trajectory_infeed["BFFPC - Random sequence 3"], 
         linewidth = linew, color = "r")
ax3.plot(with_trajectory_infeed["Time"], with_trajectory_infeed["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "b")
ax3.set_xlabel("Time (minutes)", fontsize = fs)
ax3.set_ylabel("Dry tons/hr", fontsize = fs)
ax3.set_ylim([0, 6.35])
ax3.legend(["BFFPC - Random sequence 3", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax3.tick_params(axis = "x", labelsize = fs)
ax3.tick_params(axis = "y", labelsize = fs)
ax4.plot(with_trajectory_infeed["Time"], with_trajectory_infeed["BFFPC - Random sequence 4"], 
         linewidth = linew, color = "r")
ax4.plot(with_trajectory_infeed["Time"], with_trajectory_infeed["HPC - 100M,60L,40H"], 
         linewidth = linew, color = "b")
ax4.set_xlabel("Time (minutes)", fontsize = fs)
ax4.set_ylabel("Dry tons/hr", fontsize = fs)
ax4.set_ylim([0, 6.35])
ax4.legend(["BFFPC - Random sequence 4", "HPC - 100M,60L,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax4.tick_params(axis = "x", labelsize = fs)
ax4.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v5/Figures/infeed_with.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Reactor trajectory

# %%
with_trajectory_reactor = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper\With.xlsx', 
    sheet_name = 'Feeding')

fig, ([ax1, ax2], [ax3, ax4]) = plt.subplots(2, 2, figsize = (fig1, fig2))
ax1.plot(with_trajectory_reactor["Time"], with_trajectory_reactor["BFFPC - Random sequence 1"], 
         linewidth = linew, color = "r")
ax1.plot(with_trajectory_reactor["Time"], with_trajectory_reactor["HPC - 40H,60L,100M"], 
         linewidth = linew, color = "b")
ax1.set_xlabel("Time (minutes)", fontsize = fs)
ax1.set_ylabel("Dry tons/hr", fontsize = fs)
ax1.set_ylim([0, 16])
ax1.legend(["BFFPC - Random sequence 1", "HPC - 40H,60L,100M"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax1.tick_params(axis = "x", labelsize = fs)
ax1.tick_params(axis = "y", labelsize = fs)
ax2.plot(with_trajectory_reactor["Time"], with_trajectory_reactor["BFFPC - Random sequence 2"], 
         linewidth = linew, color = "r")
ax2.plot(with_trajectory_reactor["Time"], with_trajectory_reactor["HPC - 60L,100M,40H"], 
         linewidth = linew, color = "b")
ax2.set_xlabel("Time (minutes)", fontsize = fs)
ax2.set_ylabel("Dry tons/hr", fontsize = fs)
ax2.set_ylim([0, 16])
ax2.legend(["BFFPC - Random sequence 2", "HPC - 60L,100M,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax2.tick_params(axis = "x", labelsize = fs)
ax2.tick_params(axis = "y", labelsize = fs)
ax3.plot(with_trajectory_reactor["Time"], with_trajectory_reactor["BFFPC - Random sequence 3"], 
         linewidth = linew, color = "r")
ax3.plot(with_trajectory_reactor["Time"], with_trajectory_reactor["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "b")
ax3.set_xlabel("Time (minutes)", fontsize = fs)
ax3.set_ylabel("Dry tons/hr", fontsize = fs)
ax3.set_ylim([0, 16])
ax3.legend(["BFFPC - Random sequence 3", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax3.tick_params(axis = "x", labelsize = fs)
ax3.tick_params(axis = "y", labelsize = fs)
ax4.plot(with_trajectory_reactor["Time"], with_trajectory_reactor["BFFPC - Random sequence 4"], 
         linewidth = linew, color = "r")
ax4.plot(with_trajectory_reactor["Time"], with_trajectory_reactor["HPC - 100M,60L,40H"], 
         linewidth = linew, color = "b")
ax4.set_xlabel("Time (minutes)", fontsize = fs)
ax4.set_ylabel("Dry tons/hr", fontsize = fs)
ax4.set_ylim([0, 16])
ax4.legend(["BFFPC - Random sequence 4", "HPC - 100M,60L,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax4.tick_params(axis = "x", labelsize = fs)
ax4.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v5/Figures/reactor_with.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Inventory trajectory

# %%
with_trajectory_inventory = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper\With.xlsx', 
    sheet_name = 'Inventory')

fig, ([ax1, ax2], [ax3, ax4]) = plt.subplots(2, 2, figsize = (fig1, fig2))
ax1.plot(with_trajectory_inventory["Time"], with_trajectory_inventory["BFFPC - Random sequence 1"], 
         linewidth = linew, color = "r")
ax1.plot(with_trajectory_inventory["Time"], with_trajectory_inventory["HPC - 40H,60L,100M"], 
         linewidth = linew, color = "b")
ax1.set_xlabel("Time (minutes)", fontsize = fs)
ax1.set_ylabel("Dry tons", fontsize = fs)
ax1.set_ylim([0, 12])
ax1.legend(["BFFPC - Random sequence 1", "HPC - 40H,60L,100M"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax1.tick_params(axis = "x", labelsize = fs)
ax1.tick_params(axis = "y", labelsize = fs)
ax2.plot(with_trajectory_inventory["Time"], with_trajectory_inventory["BFFPC - Random sequence 2"], 
         linewidth = linew, color = "r")
ax2.plot(with_trajectory_inventory["Time"], with_trajectory_inventory["HPC - 60L,100M,40H"], 
         linewidth = linew, color = "b")
ax2.set_xlabel("Time (minutes)", fontsize = fs)
ax2.set_ylabel("Dry tons", fontsize = fs)
ax2.set_ylim([0, 12])
ax2.legend(["BFFPC - Random sequence 2", "HPC - 60L,100M,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax2.tick_params(axis = "x", labelsize = fs)
ax2.tick_params(axis = "y", labelsize = fs)
ax3.plot(with_trajectory_inventory["Time"], with_trajectory_inventory["BFFPC - Random sequence 3"], 
         linewidth = linew, color = "r")
ax3.plot(with_trajectory_inventory["Time"], with_trajectory_inventory["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "b")
ax3.set_xlabel("Time (minutes)", fontsize = fs)
ax3.set_ylabel("Dry tons", fontsize = fs)
ax3.set_ylim([0, 12])
ax3.legend(["BFFPC - Random sequence 3", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax3.tick_params(axis = "x", labelsize = fs)
ax3.tick_params(axis = "y", labelsize = fs)
ax4.plot(with_trajectory_inventory["Time"], with_trajectory_inventory["BFFPC - Random sequence 4"], 
         linewidth = linew, color = "r")
ax4.plot(with_trajectory_inventory["Time"], with_trajectory_inventory["HPC - 100M,60L,40H"], 
         linewidth = linew, color = "b")
ax4.set_xlabel("Time (minutes)", fontsize = fs)
ax4.set_ylabel("Dry tons", fontsize = fs)
ax4.set_ylim([0, 12])
ax4.legend(["BFFPC - Random sequence 4", "HPC - 100M,60L,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax4.tick_params(axis = "x", labelsize = fs)
ax4.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v5/Figures/inventory_with.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

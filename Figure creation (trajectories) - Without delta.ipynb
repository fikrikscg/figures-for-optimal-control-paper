# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functools import reduce

# %% [markdown]
# # Variables

# %%
fs = 20
dpi_qual = 900
linew = 2.5
fig1 = 17
fig2 = 6

# %% [markdown]
# # Templates

# %%
fig, ax = plt.subplots(1, 1, figsize = (18,6))
ax.plot(new_merged_data['VG Infeed Current_x'])
ax.set_xlabel("Time", fontsize = fs)
ax.set_ylabel("Amp", fontsize = fs)
ax.legend(["No DG", "DG at center 1", "DG at center 3"], fontsize  = fs, frameon = False)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing v2/Figures', dpi = dpi_qual)
# ax.axvline(x = f1s, ymin = 0.5, ymax = 0.75, color = 'red')
# ax.set_title("Current of DC-5 (Red lines show stoppage times in Vermeer grinder)", fontsize = 14)
# ax.plot(vol, nodg, linestyle = '-', marker = "o")
# fig.savefig('Fig6a.jpg', dpi = 900)
# fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize = (18, 18))
# ax1.legend(['NSGA-II', 'Hybrid-NSGA-II'], fontsize = 13, frameon = False, loc = 'upper left')
# ax1.set_xticks([]) # To remove x ticks

# %% [markdown]
# # Infeed trajectory

# %% [markdown]
# ## Main results

# %%
without_trajectory_infeed = pd.read_excel(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/Without.xlsx', 
    sheet_name = 'Infeed')

fig, ax = plt.subplots(1, 1, figsize = (fig1, fig2))
ax.plot(without_trajectory_infeed["Time"], without_trajectory_infeed["BFFPC - Random sequence 6"], 
         linewidth = linew, color = "purple", linestyle = "dashed")
ax.plot(without_trajectory_infeed["Time"], without_trajectory_infeed["HPC - 6L,10M,4H X10"],
         linewidth = linew, color = "g")
ax.set_xlabel("Time (minutes)", fontsize = fs)
ax.set_ylabel("Dry Mg/hour", fontsize = fs)
ax.set_ylim([0, 6.5])
ax.legend(["BFFPC - Random pattern", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax.tick_params(axis = "x", labelsize = fs)
ax.tick_params(axis = "y", labelsize = fs)
fig.savefig('/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/infeed_without.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
with_trajectory_infeed = pd.read_excel(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/With.xlsx', 
    sheet_name = 'Infeed')

fig, ax = plt.subplots(1, 1, figsize = (fig1, fig2))
ax.plot(with_trajectory_infeed["Time"], with_trajectory_infeed["BFFPC - Random sequence 6"], 
         linewidth = linew, color = "purple", linestyle = "dashed")
ax.plot(with_trajectory_infeed["Time"], with_trajectory_infeed["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "g")
ax.set_xlabel("Time (minutes)", fontsize = fs)
ax.set_ylabel("Dry Mg/hour", fontsize = fs)
ax.set_ylim([0, 6.5])
ax.legend(["BFFPC - Random pattern", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax.tick_params(axis = "x", labelsize = fs)
ax.tick_params(axis = "y", labelsize = fs)
fig.savefig('/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/infeed_with.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Sensitivity analysis (with fractional milling case)

# %%
with_trajectory_infeed_all = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/With.xlsx', 
    sheet_name = 'Infeed_All')

fig, ax = plt.subplots(1, 1, figsize = (fig1, fig2))
ax.plot(with_trajectory_infeed_all["Time"], with_trajectory_infeed_all["BFFPC - Random sequence 1"], 
         linewidth = linew)
ax.plot(with_trajectory_infeed_all["Time"], with_trajectory_infeed_all["BFFPC - Random sequence 2"], 
         linewidth = linew)
ax.plot(with_trajectory_infeed_all["Time"], with_trajectory_infeed_all["BFFPC - Random sequence 3"], 
         linewidth = linew)
ax.plot(with_trajectory_infeed_all["Time"], with_trajectory_infeed_all["BFFPC - Random sequence 4"], 
         linewidth = linew)
ax.plot(with_trajectory_infeed_all["Time"], with_trajectory_infeed_all["BFFPC - Random sequence 6"], 
         linewidth = linew)
ax.set_xlabel("Time (minutes)", fontsize = fs)
ax.set_ylabel("Dry tons/hr", fontsize = fs)
ax.set_ylim([0, 6.8])
ax.legend(["R. s. 1", "R. s. 2", "R. s. 3", "R. s. 4", "R. s. 6"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 5)
ax.tick_params(axis = "x", labelsize = fs)
ax.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/infeed_with_bffpc_all.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
fig, ax = plt.subplots(1, 1, figsize = (fig1, fig2))
ax.plot(with_trajectory_infeed_all["Time"], with_trajectory_infeed_all["HPC - 40H,60L,100M"], 
         linewidth = linew)
ax.plot(with_trajectory_infeed_all["Time"], with_trajectory_infeed_all["HPC - 40H,100M,60L"], 
         linewidth = linew)
ax.plot(with_trajectory_infeed_all["Time"], with_trajectory_infeed_all["HPC - 60L,100M,40H"], 
         linewidth = linew)
ax.plot(with_trajectory_infeed_all["Time"], with_trajectory_infeed_all["HPC - 100M,60L,40H"], 
         linewidth = linew)
ax.set_xlabel("Time (minutes)", fontsize = fs)
ax.set_ylabel("Dry tons/hr", fontsize = fs)
ax.set_ylim([0, 6.8])
ax.legend(["40H,60L,100M", "40H,100M,60L", "60L,100M,40H", "100M,60L,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 4)
ax.tick_params(axis = "x", labelsize = fs)
ax.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/infeed_with_hpc_all.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# # Reactor trajectory

# %% [markdown]
# ## Main results

# %%
without_trajectory_reactor = pd.read_excel(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/Without.xlsx', 
    sheet_name = 'Feeding')

fig, ax = plt.subplots(1, 1, figsize = (fig1, fig2))
ax.plot(without_trajectory_reactor["Time"], without_trajectory_reactor["BFFPC - Random sequence 6"], 
         linewidth = linew, color = "purple", linestyle = "dashed")
ax.plot(without_trajectory_reactor["Time"], without_trajectory_reactor["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "g")
ax.set_xlabel("Time (minutes)", fontsize = fs)
ax.set_ylabel("Dry Mg/hour", fontsize = fs)
ax.set_ylim([0, 9])
ax.legend(["BFFPC - Random pattern", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax.tick_params(axis = "x", labelsize = fs)
ax.tick_params(axis = "y", labelsize = fs)
fig.savefig('/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/reactor_without.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
with_trajectory_reactor = pd.read_excel(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/With.xlsx', 
    sheet_name = 'Feeding')

fig, ax = plt.subplots(1, 1, figsize = (fig1, fig2))
ax.plot(with_trajectory_reactor["Time"], with_trajectory_reactor["BFFPC - Random sequence 6"], 
         linewidth = linew, color = "purple", linestyle = "dashed")
ax.plot(with_trajectory_reactor["Time"], with_trajectory_reactor["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "g")
ax.set_xlabel("Time (minutes)", fontsize = fs)
ax.set_ylabel("Dry Mg/hour", fontsize = fs)
ax.set_ylim([0, 9])
ax.legend(["BFFPC - Random pattern", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax.tick_params(axis = "x", labelsize = fs)
ax.tick_params(axis = "y", labelsize = fs)
fig.savefig('/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/reactor_with.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Sensitivity analysis (with fractional milling case)

# %%
with_trajectory_reactor_all = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/With.xlsx', 
    sheet_name = 'Feeding_All')

fig, ax = plt.subplots(1, 1, figsize = (fig1, fig2))
ax.plot(with_trajectory_reactor_all["Time"], with_trajectory_reactor_all["BFFPC - Random sequence 1"], 
         linewidth = linew)
ax.plot(with_trajectory_reactor_all["Time"], with_trajectory_reactor_all["BFFPC - Random sequence 2"], 
         linewidth = linew)
ax.plot(with_trajectory_reactor_all["Time"], with_trajectory_reactor_all["BFFPC - Random sequence 3"], 
         linewidth = linew)
ax.plot(with_trajectory_reactor_all["Time"], with_trajectory_reactor_all["BFFPC - Random sequence 4"], 
         linewidth = linew)
ax.plot(with_trajectory_reactor_all["Time"], with_trajectory_reactor_all["BFFPC - Random sequence 6"], 
         linewidth = linew)
ax.set_xlabel("Time (minutes)", fontsize = fs)
ax.set_ylabel("Dry tons/hr", fontsize = fs)
ax.set_ylim([0, 9])
ax.legend(["R. s. 1", "R. s. 2", "R. s. 3", "R. s. 4", "R. s. 6"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 5)
ax.tick_params(axis = "x", labelsize = fs)
ax.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/reactor_with_bffpc_all.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
fig, ax = plt.subplots(1, 1, figsize = (fig1, fig2))
ax.plot(with_trajectory_reactor_all["Time"], with_trajectory_reactor_all["HPC - 40H,60L,100M"], 
         linewidth = linew)
ax.plot(with_trajectory_reactor_all["Time"], with_trajectory_reactor_all["HPC - 40H,100M,60L"], 
         linewidth = linew)
ax.plot(with_trajectory_reactor_all["Time"], with_trajectory_reactor_all["HPC - 60L,100M,40H"], 
         linewidth = linew)
ax.plot(with_trajectory_reactor_all["Time"], with_trajectory_reactor_all["HPC - 100M,60L,40H"], 
         linewidth = linew)
ax.set_xlabel("Time (minutes)", fontsize = fs)
ax.set_ylabel("Dry tons/hr", fontsize = fs)
ax.set_ylim([0, 9])
ax.legend(["40H,60L,100M", "40H,100M,60L", "60L,100M,40H", "100M,60L,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 4)
ax.tick_params(axis = "x", labelsize = fs)
ax.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/reactor_with_hpc_all.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# # Inventory trajectory

# %% [markdown]
# ## Main results

# %%
without_trajectory_inventory = pd.read_excel(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/Without.xlsx', 
    sheet_name = 'Inventory')

fig, ax = plt.subplots(1, 1, figsize = (fig1, fig2))
ax.plot(without_trajectory_inventory["Time"], without_trajectory_inventory["BFFPC - Random sequence 6"], 
         linewidth = linew, color = "purple", linestyle = "dashed")
ax.plot(without_trajectory_inventory["Time"], without_trajectory_inventory["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "g")
ax.set_xlabel("Time (minutes)", fontsize = fs)
ax.set_ylabel("Dry Mg", fontsize = fs)
ax.set_ylim([0, 2.2])
ax.legend(["BFFPC - Random pattern", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax.tick_params(axis = "x", labelsize = fs)
ax.tick_params(axis = "y", labelsize = fs)
fig.savefig('/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/inventory_without_twofeeding.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
with_trajectory_inventory = pd.read_excel(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/With.xlsx', 
    sheet_name = 'Inventory')

fig, ax = plt.subplots(1, 1, figsize = (fig1, fig2))
ax.plot(with_trajectory_inventory["Time"], with_trajectory_inventory["BFFPC - Random sequence 6"], 
         linewidth = linew, color = "purple", linestyle = "dashed")
ax.plot(with_trajectory_inventory["Time"], with_trajectory_inventory["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "g")
ax.set_xlabel("Time (minutes)", fontsize = fs)
ax.set_ylabel("Dry Mg", fontsize = fs)
ax.set_ylim([0, 2.2])
ax.legend(["BFFPC - Random pattern", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax.tick_params(axis = "x", labelsize = fs)
ax.tick_params(axis = "y", labelsize = fs)
fig.savefig('/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/inventory_with_twofeeding.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Sensitivity analysis (with fractional milling case

# %%
with_trajectory_inventory_all = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/With.xlsx', 
    sheet_name = 'Inventory_All')

fig, ax = plt.subplots(1, 1, figsize = (fig1, fig2))
ax.plot(with_trajectory_inventory_all["Time"], with_trajectory_inventory_all["BFFPC - Random sequence 1"], 
         linewidth = linew)
ax.plot(with_trajectory_inventory_all["Time"], with_trajectory_inventory_all["BFFPC - Random sequence 2"], 
         linewidth = linew)
ax.plot(with_trajectory_inventory_all["Time"], with_trajectory_inventory_all["BFFPC - Random sequence 3"], 
         linewidth = linew)
ax.plot(with_trajectory_inventory_all["Time"], with_trajectory_inventory_all["BFFPC - Random sequence 4"], 
         linewidth = linew)
ax.plot(with_trajectory_inventory_all["Time"], with_trajectory_inventory_all["BFFPC - Random sequence 6"], 
         linewidth = linew)
ax.set_xlabel("Time (minutes)", fontsize = fs)
ax.set_ylabel("Dry tons", fontsize = fs)
ax.set_ylim([0, 13])
ax.legend(["R. s. 1", "R. s. 2", "R. s. 3", "R. s. 4", "R. s. 6"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 5)
ax.tick_params(axis = "x", labelsize = fs)
ax.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/inventory_with_bffpc_all.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
fig, ax = plt.subplots(1, 1, figsize = (fig1, fig2))
ax.plot(with_trajectory_inventory_all["Time"], with_trajectory_inventory_all["HPC - 40H,60L,100M"], 
         linewidth = linew)
ax.plot(with_trajectory_inventory_all["Time"], with_trajectory_inventory_all["HPC - 40H,100M,60L"], 
         linewidth = linew)
ax.plot(with_trajectory_inventory_all["Time"], with_trajectory_inventory_all["HPC - 60L,100M,40H"], 
         linewidth = linew)
ax.plot(with_trajectory_inventory_all["Time"], with_trajectory_inventory_all["HPC - 100M,60L,40H"], 
         linewidth = linew)
ax.set_xlabel("Time (minutes)", fontsize = fs)
ax.set_ylabel("Dry tons", fontsize = fs)
ax.set_ylim([0, 13])
ax.legend(["40H,60L,100M", "40H,100M,60L", "60L,100M,40H", "100M,60L,40H"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 4)
ax.tick_params(axis = "x", labelsize = fs)
ax.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/inventory_with_hpc_all.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# # Step sizes of bale in-feed rate and reactor feeding rates (from experiments)

# %%
cumulative_optimal = [0, 0.3225, 0.671111111, 0.998333333, 1.402555556, 1.763722222, 2.126777778, 
                              2.508277778, 2.906166667, 3.265777778, 3.618555556, 3.968055556, 4.3235, 
                              4.677333333, 5.03, 5.385833333, 5.797166667, 6.124944444, 6.387222222, 
                              6.726111111, 7.07833333]
bale_infeed_optimal = [1.4514944, 1.27511759, 1.314107621, 1.164776378, 1.193112321, 1.236879792, 1.203237494, 
                     1.165076575, 1.23611353, 1.234341694, 1.30042685, 1.288887552, 1.271681387, 1.255309429, 
                     1.272182153, 1.133612421, 1.15689024, 1.58762004, 1.175175077, 1.19228, 0]
reactor_feeding_optimal = [1.255, 1.2, 1.2, 1.2, 1.2, 1.25, 1.2, 1.18, 1.28, 1.2, 1.2, 1.25, 1.28, 1.2, 1.28, 
                           1.16, 1.2, 1.334, 1.24, 1.2, 0]

cumulative_random = [0, 0.421111111, 0.724777778, 1.047777778, 1.430833333, 1.762388889, 2.116944444, 2.488166667, 
                     2.840166667, 3.292722222, 3.646888889, 3.976555556, 4.370833333, 4.724388889, 5.083, 
                     5.5135, 5.91, 6.276944444, 6.589444444, 6.919, 7.227222222]
bale_infeed_random = [1.092211238, 1.643088474, 1.418352693, 1.127302757, 1.384489255, 1.287001557, 
                      1.165681207, 1.193256227, 0.793813841, 1.260238667, 1.362151911, 1.11592452, 1.180308536,
                      1.151020443, 0.996743396, 1.153141831, 1.129825221, 1.361501747, 1.30755617, 1.383341139,
                      0]
reactor_feeding_random = [1.05, 1.56, 1.382, 1.1, 1.4, 1.3, 1.1, 1.15, 0.75, 1.25, 1.28, 1.1, 1.25, 1.1, 
                          1.0, 1.1, 1.14, 1.34, 1.29, 1.38, 0]

fig, ax = plt.subplots(1, 1, figsize = (fig1, fig2))
ax.step([number * 60 for number in cumulative_optimal], reactor_feeding_optimal, linewidth = linew, color = "magenta", where = "post")
ax.step([number * 60 for number in cumulative_optimal], bale_infeed_optimal, linewidth = linew, color = "indigo", linestyle = "dashed", where = "post")
ax.set_xlabel("Time (minutes)", fontsize = fs)
ax.set_ylabel("Dry Mg", fontsize = fs)
ax.set_ylim([0.6, 1.8])
ax.set_xlim([0, 460])
ax.legend(["Reactor Feeding Rate", "Bale In-Feed Rate"], fontsize  = fs, frameon = False, loc = 'upper center', ncol = 2)
ax.tick_params(axis = "x", labelsize = fs)
ax.tick_params(axis = "y", labelsize = fs)
fig.savefig('/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/experiment_optimal.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

fig, ax = plt.subplots(1, 1, figsize = (fig1, fig2))
ax.step([number * 60 for number in cumulative_random], reactor_feeding_random, linewidth = linew, color = "magenta", where = "post")
ax.step([number * 60 for number in cumulative_random], bale_infeed_random, linewidth = linew, color = "indigo", linestyle = "dashed", where = "post")
ax.set_xlabel("Time (minutes)", fontsize = fs)
ax.set_ylabel("Dry Mg", fontsize = fs)
ax.set_ylim([0.6, 1.8])
ax.set_xlim([0, 460])
ax.legend(["Reactor Feeding Rate", "Bale In-Feed Rate"], fontsize  = fs, frameon = False, loc = 'upper center', ncol = 2)
ax.tick_params(axis = "x", labelsize = fs)
ax.tick_params(axis = "y", labelsize = fs)
fig.savefig('/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/experiment_random.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# # Do not use the followings!!!

# %%
without_trajectory_infeed = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/Without.xlsx', 
    sheet_name = 'Infeed')
with_trajectory_infeed = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/With.xlsx', 
    sheet_name = 'Infeed')

fig, ([ax1, ax2]) = plt.subplots(1, 2, figsize = (fig1, fig2))
ax1.plot(without_trajectory_infeed["Time"], without_trajectory_infeed["BFFPC - Random sequence 5"], 
         linewidth = linew, color = "r")
ax1.plot(without_trajectory_infeed["Time"], without_trajectory_infeed["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "b")
ax1.set_xlabel("Time (minutes)", fontsize = fs)
ax1.set_ylabel("Dry tons/hr", fontsize = fs)
ax1.set_ylim([0, 6.5])
ax1.legend(["BFFPC - Random sequence 5", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax1.tick_params(axis = "x", labelsize = fs)
ax1.tick_params(axis = "y", labelsize = fs)
ax2.plot(with_trajectory_infeed["Time"], with_trajectory_infeed["BFFPC - Random sequence 5"], 
         linewidth = linew, color = "r")
ax2.plot(with_trajectory_infeed["Time"], with_trajectory_infeed["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "b")
ax2.set_xlabel("Time (minutes)", fontsize = fs)
ax2.set_ylabel("Dry tons/hr", fontsize = fs)
ax2.set_ylim([0, 6.5])
ax2.legend(["BFFPC - Random sequence 5", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax2.tick_params(axis = "x", labelsize = fs)
ax2.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/infeed.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
without_trajectory_reactor = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/Without.xlsx', 
    sheet_name = 'Feeding')
with_trajectory_reactor = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/With.xlsx', 
    sheet_name = 'Feeding')

fig, ([ax1, ax2]) = plt.subplots(1, 2, figsize = (fig1, fig2))
ax1.plot(without_trajectory_reactor["Time"], without_trajectory_reactor["BFFPC - Random sequence 5"], 
         linewidth = linew, color = "r")
ax1.plot(without_trajectory_reactor["Time"], without_trajectory_reactor["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "b")
ax1.set_xlabel("Time (minutes)", fontsize = fs)
ax1.set_ylabel("Dry tons/hr", fontsize = fs)
ax1.set_ylim([0, 9])
ax1.legend(["BFFPC - Random sequence 5", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax1.tick_params(axis = "x", labelsize = fs)
ax1.tick_params(axis = "y", labelsize = fs)
ax2.plot(with_trajectory_reactor["Time"], with_trajectory_reactor["BFFPC - Random sequence 5"], 
         linewidth = linew, color = "r")
ax2.plot(with_trajectory_reactor["Time"], with_trajectory_reactor["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "b")
ax2.set_xlabel("Time (minutes)", fontsize = fs)
ax2.set_ylabel("Dry tons/hr", fontsize = fs)
ax2.set_ylim([0, 9])
ax2.legend(["BFFPC - Random sequence 5", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax2.tick_params(axis = "x", labelsize = fs)
ax2.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/reactor.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
without_trajectory_inventory = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/Without.xlsx', 
    sheet_name = 'Inventory')
with_trajectory_inventory = pd.read_excel(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Run results/New input data/For paper (Trials with delta and iterative process)/Delta removal from objective function (multi-step procedure)/With.xlsx', 
    sheet_name = 'Inventory')

fig, ([ax1, ax2]) = plt.subplots(1, 2, figsize = (fig1, fig2))
ax1.plot(without_trajectory_inventory["Time"], without_trajectory_inventory["BFFPC - Random sequence 5"], 
         linewidth = linew, color = "r")
ax1.plot(without_trajectory_inventory["Time"], without_trajectory_inventory["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "b")
ax1.set_xlabel("Time (minutes)", fontsize = fs)
ax1.set_ylabel("Dry tons", fontsize = fs)
ax1.set_ylim([0, 3.6])
ax1.legend(["BFFPC - Random sequence 5", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax1.tick_params(axis = "x", labelsize = fs)
ax1.tick_params(axis = "y", labelsize = fs)
ax2.plot(with_trajectory_inventory["Time"], with_trajectory_inventory["BFFPC - Random sequence 5"], 
         linewidth = linew, color = "r")
ax2.plot(with_trajectory_inventory["Time"], with_trajectory_inventory["HPC - 6L,10M,4H X10"], 
         linewidth = linew, color = "b")
ax2.set_xlabel("Time (minutes)", fontsize = fs)
ax2.set_ylabel("Dry tons", fontsize = fs)
ax2.set_ylim([0, 3.6])
ax2.legend(["BFFPC - Random sequence 5", "HPC - 6L,10M,4H X10"], fontsize  = fs, frameon = False, 
           loc = 'upper center', ncol = 2)
ax2.tick_params(axis = "x", labelsize = fs)
ax2.tick_params(axis = "y", labelsize = fs)
fig.savefig('C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/inventory.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

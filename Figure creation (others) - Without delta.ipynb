# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
fig1 = 8
fig2 = 6
fs = 20
dpi_qual = 900
linew = 2.5
bar_width = 0.2

# %% [markdown]
# # Average feeding and variability

# %% [markdown]
# ## Main text

# %%
name_controls = ['BFFPC', 'HPC']

withoutmilling_feeding = [2.713, 2.72293975]
withoutmilling_var = [5.48, 100]

x = np.arange(2)
fig, ax1 = plt.subplots(1, 1, figsize = (fig1, fig2))
w = 0.3

plt.xticks(x + w / 2, name_controls, rotation = 'horizontal')
pop = ax1.bar(x, withoutmilling_feeding, width = w, color = 'b', align = 'center')
errormin_feeding_without = [0, 0] # [FK, I added this for revision]
errormax_feeding_without = [0, 0] # [FK, I added this for revision]
plt.errorbar(x, withoutmilling_feeding, yerr = [errormin_feeding_without, errormax_feeding_without], 
             color = 'r', fmt = 'o', elinewidth = 2) # [FK, I added this for revision]
ax1.set_ylabel("Av. Feed. (dry Mg/hour)", fontsize = fs)
ax1.set_ylim(0, 5)
ax1.tick_params(axis = 'y', labelsize = fs)
ax1.tick_params(axis = 'x', labelsize = fs)

ax2 = ax1.twinx()
gdp = ax2.bar(x + w, withoutmilling_var, width = w, color = 'y', align = 'center')
errormin_var_without = [5.48, 0] # [FK, I added this for revision]
errormax_var_without = [22.80, 0] # [FK, I added this for revision]
plt.errorbar(x + w, withoutmilling_var, yerr = [errormin_var_without, errormax_var_without], 
             color = 'r', fmt = 'o', elinewidth = 2) # [FK, I added this for revision]
ax2.set_ylabel("Reduction in Coef. Var. (%)", fontsize = fs)
ax2.set_ylim(0, 140)
ax2.tick_params(axis = "y", labelsize = fs)
plt.legend([pop, gdp], ['Av. Feed.', 'Reduction'], frameon = False, fontsize = fs, ncol = 2)

plt.savefig(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/feedvar_without_maintext.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

withmilling_feeding = [3.696, 3.780580535]
withmilling_var = [62.38, 100]

xx = np.arange(2)
fig, ax1 = plt.subplots(1, 1, figsize = (fig1, fig2))
w = 0.3

plt.xticks(xx + w / 2, name_controls, rotation = 'horizontal')
pop = ax1.bar(xx, withmilling_feeding, width = w, color = 'b', align = 'center')
errormin_feeding_with = [0.092, 0] # [FK, I added this for revision]
errormax_feeding_with = [0, 0] # [FK, I added this for revision]
plt.errorbar(xx, withmilling_feeding, yerr = [errormin_feeding_with, errormax_feeding_with], 
             color = 'r', fmt = 'o', elinewidth = 2) # [FK, I added this for revision]
ax1.set_ylabel("Av. Feed. (dry Mg/hour)", fontsize = fs)
ax1.set_ylim(0, 5)
ax1.tick_params(axis = 'y', labelsize = fs)
ax1.tick_params(axis = 'x', labelsize = fs)

ax2 = ax1.twinx()
gdp = ax2.bar(xx + w, withmilling_var, width = w, color = 'y', align = 'center')
errormin_var_with = [5.79, 0] # [FK, I added this for revision]
errormax_var_with = [0.51, 0] # [FK, I added this for revision]
plt.errorbar(xx + w, withmilling_var, yerr = [errormin_var_with, errormax_var_with], 
             color = 'r', fmt = 'o', elinewidth = 2) # [FK, I added this for revision]
ax2.set_ylabel("Reduction in Coef. Var. (%)", fontsize = fs)
ax2.set_ylim(0, 140)
ax2.tick_params(axis = "y", labelsize = fs)
plt.legend([pop, gdp], ['Av. Feed.', 'Reduction'], frameon = False, fontsize = fs, ncol = 2)
# plt.show()

plt.savefig(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/feedvar_with_maintext.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
# name_controls = ['BFFPC', 'HPC']

# withoutmilling = [2.713306712, 2.72293975]
# withmilling = [3.603365823, 3.780580535]

# cap_bins = [6, 6]

# plt.figure(figsize = (fig1, fig2))
# N = len(withoutmilling)
# ind = np.arange(N)
# plt.ylim(0, 5)
# plt.bar(ind, withoutmilling, bar_width, color = 'b', label = 'Without fractional milling')
# plt.bar(ind + bar_width, withmilling, bar_width, color = 'y', label = 'With fractional milling')
# # plt.legend(frameon = False, fontsize = fs, ncol = 2)
# plt.legend(frameon = False, fontsize = fs, loc = 'upper left')
# plt.ylabel("Dry tons", fontsize = fs)
# plt.tick_params(axis = 'y', labelsize = fs)
# plt.tick_params(axis = 'x', labelsize = fs)

# axes2 = plt.twinx()
# axes2.plot(name_controls, cap_bins)
# axes2.set_ylim(0, 4)
# axes2.get_yaxis().set_visible(False)

# plt.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/afeed_maintext.pdf', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)


# withoutmilling_var = [0.565467129, 1.03E-15]
# withmilling_var = [0.245251587, 7.85E-16]

# cap_bins_var = [2, 2]

# plt.figure(figsize = (fig1, fig2))
# N = len(withoutmilling_var)
# ind = np.arange(N)
# plt.ylim(0, 1)
# plt.bar(ind, withoutmilling_var, bar_width, color = 'b', label = 'Without fractional milling')
# plt.bar(ind + bar_width, withmilling_var, bar_width, color = 'y', label = 'With fractional milling')
# # plt.legend(frameon = False, fontsize = fs, ncol = 2)
# plt.legend(frameon = False, fontsize = fs, loc = 'upper left')
# plt.tick_params(axis = 'y', labelsize = fs)
# plt.tick_params(axis = 'x', labelsize = fs)

# axes2 = plt.twinx()
# axes2.plot(name_controls, cap_bins_var)
# axes2.set_ylim(0, 1)
# axes2.get_yaxis().set_visible(False)

# plt.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/var_maintext.pdf', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
# name = ['BFFPC', 'HPC']
# afeeding_without = [2.713306712, 2.72293975]
# vfeeding_without = [0.565467129, 1.03E-15]

# plt.figure(figsize = (fig1, fig2))
# N = len(afeeding_without)
# ind = np.arange(N)
# plt.ylim(0, 4.9)
# plt.bar(ind, afeeding_without, bar_width, color = 'g', label = 'Av. Feed.')
# # plt.bar(ind + width, cap_without_fix_str, width, color = 'y', label = 'Storage Bin Max. Inv.')     
# plt.legend(frameon = False, fontsize = fs)
# plt.ylabel("Dry tons", fontsize = fs)
# plt.tick_params(axis = 'y', labelsize = fs)
# plt.tick_params(axis = 'x', labelsize = fs)   

# axes2 = plt.twinx()
# axes2.plot(name, vfeeding_without, color = 'k', label = 'Coef. Var.', linewidth = linew)
# axes2.set_ylim(0, 0.8)
# axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
# axes2.set_ylabel('Coef. Var.', fontsize = fs)
# axes2.tick_params(axis = "y", labelsize = fs)

# plt.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/feeding_without.pdf', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
# afeeding_with = [3.603365823, 3.780580535]
# vfeeding_with = [0.245251587, 7.85E-16]

# plt.figure(figsize = (fig1, fig2))
# N = len(afeeding_with)
# ind = np.arange(N)
# plt.ylim(0, 4.9)
# plt.bar(ind, afeeding_with, bar_width, color = 'g', label = 'Av. Feed.')
# # plt.bar(ind + width, cap_without_fix_str, width, color = 'y', label = 'Storage Bin Max. Inv.')     
# plt.legend(loc = 'upper right', frameon = False, fontsize = fs)
# plt.ylabel("Dry tons", fontsize = fs)
# plt.tick_params(axis = 'y', labelsize = fs)
# plt.tick_params(axis = 'x', labelsize = fs)

# axes2 = plt.twinx()
# axes2.plot(name, vfeeding_with, color = 'k', label = 'Coef. Var.', linewidth = linew)
# axes2.set_ylim(0, 0.8)
# axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
# axes2.set_ylabel('Coef. Var.', fontsize = fs)
# axes2.tick_params(axis = "y", labelsize = fs)

# plt.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/feeding_with.pdf', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Sensitivity analysis (with fractional milling case)

# %%
afeeding_with_bffpc_all = [3.696, 3.696, 3.696, 3.696, 3.603, 3.603]
vfeeding_with_bffpc_all = [62.38, 62.79, 57.90, 62.89, 56.59, 56.63]

x = np.arange(6)
fig, ax1 = plt.subplots(1, 1, figsize = (18, 6))
w = 0.3

plt.xticks(x + w / 2, ["Baseline", "R.p. 1", "R.p. 2", "R.p. 3", "R.p. 4", "R.p. 5"], rotation = 'horizontal')
pop = ax1.bar(x, afeeding_with_bffpc_all, width = w, color = 'b', align = 'center')
ax1.set_ylabel("Av. Feed. (dry Mg/hour)", fontsize = fs)
ax1.set_ylim(0, 5)
ax1.tick_params(axis = 'y', labelsize = fs)
ax1.tick_params(axis = 'x', labelsize = fs)

ax2 = ax1.twinx()
gdp = ax2.bar(x + w, vfeeding_with_bffpc_all, width = w, color = 'y', align = 'center')
ax2.set_ylabel("Reduction in Coef. Var. (%)", fontsize = fs)
ax2.set_ylim(0, 140)
ax2.tick_params(axis = "y", labelsize = fs)
plt.legend([pop, gdp], ['Av. Feed.', 'Reduction'], frameon = False, fontsize = fs, ncol = 2)
# plt.show()

plt.savefig(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/feeding_var_with_bffpc_all.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)


afeeding_with_hpc_all = [3.781, 3.484, 3.484, 3.649, 3.646]
vfeeding_with_hpc_all = [100.00, 53.36, 49.80, 100.00, 100.00]

xx = np.arange(5)
fig, ax1 = plt.subplots(1, 1, figsize = (18, 6))
w = 0.3

plt.xticks(xx + w / 2, ["Baseline", "40H,60L,100M", "40H,100M,60L", "60L,100M,40H", "100M,60L,40H"], rotation = 'horizontal')
pop = ax1.bar(xx, afeeding_with_hpc_all, width = w, color = 'b', align = 'center')
ax1.set_ylabel("Av. Feed. (dry Mg/hour)", fontsize = fs)
ax1.set_ylim(0, 5)
ax1.tick_params(axis = 'y', labelsize = fs)
ax1.tick_params(axis = 'x', labelsize = fs)

ax2 = ax1.twinx()
gdp = ax2.bar(xx + w, vfeeding_with_hpc_all, width = w, color = 'y', align = 'center')
ax2.set_ylabel("Reduction in Coef. Var. (%)", fontsize = fs)
ax2.set_ylim(0, 140)
ax2.tick_params(axis = "y", labelsize = fs)
plt.legend([pop, gdp], ['Av. Feed.', 'Reduction'], frameon = False, fontsize = fs, ncol = 2)
# plt.show()

plt.savefig(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/feeding_var_with_hpc_all.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
# name_bffpc = ["R. s. 1", "R. s. 2", "R. s. 3", "R. s. 4", "R. s. 6"]

# afeeding_with_bffpc_all = [3.696, 3.696, 3.696, 3.603, 3.696]
# vfeeding_with_bffpc_all = [0.21, 0.24, 0.21, 0.25, 0.21]

# plt.figure(figsize = (18, fig2))
# N = len(afeeding_with_bffpc_all)
# ind = np.arange(N)
# plt.ylim(0, 4.9)
# plt.bar(ind, afeeding_with_bffpc_all, bar_width, color = 'g', label = 'Av. Feed.')     
# plt.legend(loc = 'upper right', frameon = False, fontsize = fs)
# plt.ylabel("Dry tons", fontsize = fs)
# plt.tick_params(axis = 'y', labelsize = fs)
# plt.tick_params(axis = 'x', labelsize = fs)

# axes2 = plt.twinx()
# axes2.plot(name_bffpc, vfeeding_with_bffpc_all, color = 'k', label = 'Coef. Var.', linewidth = linew)
# axes2.set_ylim(0, 0.8)
# axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
# axes2.set_ylabel('Coef. Var.', fontsize = fs)
# axes2.tick_params(axis = "y", labelsize = fs)

# plt.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/feeding_var_with_bffpc_all.pdf', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
# name_hpc = ["40H,60L,100M", "40H,100M,60L", "60L,100M,40H", "100M,60L,40H"]
# afeeding_with_hpc_all = [3.484, 3.484, 3.649, 3.646]
# vfeeding_with_hpc_all = [0.26, 0.28, 0, 0]

# plt.figure(figsize = (18, fig2))
# N = len(afeeding_with_hpc_all)
# ind = np.arange(N)
# plt.ylim(0, 4.9)
# plt.bar(ind, afeeding_with_hpc_all, bar_width, color = 'g', label = 'Av. Feed.')     
# plt.legend(loc = 'upper right', frameon = False, fontsize = fs)
# plt.ylabel("Dry tons", fontsize = fs)
# plt.tick_params(axis = 'y', labelsize = fs)
# plt.tick_params(axis = 'x', labelsize = fs)

# axes2 = plt.twinx()
# axes2.plot(name_hpc, vfeeding_with_hpc_all, color = 'k', label = 'Coef. Var.', linewidth = linew)
# axes2.set_ylim(0, 0.8)
# axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
# axes2.set_ylabel('Coef. Var.', fontsize = fs)
# axes2.tick_params(axis = "y", labelsize = fs)

# plt.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/feeding_var_with_hpc_all.pdf', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# # Capacity analysis

# %% [markdown]
# ## Main text

# %%
name_buffers = ['Fixed capacity', 'Optimized buffer size capacity']

without_feeding = [2.752, 2.752]
without_var = [74.75, 71.12]

x = np.arange(2)
fig, ax1 = plt.subplots(1, 1, figsize = (fig1, fig2))
w = 0.3

plt.xticks(x + w / 2, name_buffers, rotation = 'horizontal')
pop = ax1.bar(x, without_feeding, width = w, color = 'b', align = 'center')
ax1.set_ylabel("Av. Feed. (dry Mg/hour)", fontsize = fs)
ax1.set_ylim(0, 5)
ax1.tick_params(axis = 'y', labelsize = fs)
ax1.tick_params(axis = 'x', labelsize = fs)

ax2 = ax1.twinx()
gdp = ax2.bar(x + w, without_var, width = w, color = 'y', align = 'center')
ax2.set_ylabel("Reduction in Coef. Var. (%)", fontsize = fs)
ax2.set_ylim(0, 140)
ax2.tick_params(axis = "y", labelsize = fs)
plt.legend([pop, gdp], ['Av. Feed.', 'Reduction'], frameon = False, fontsize = fs, ncol = 2)

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/feedvar_without_buffer.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

with_feeding = [3.564, 3.649]
with_var = [83.06, 100]

xx = np.arange(2)
fig, ax1 = plt.subplots(1, 1, figsize = (fig1, fig2))
w = 0.3

plt.xticks(xx + w / 2, name_buffers, rotation = 'horizontal')
pop = ax1.bar(xx, with_feeding, width = w, color = 'b', align = 'center')
ax1.set_ylabel("Av. Feed. (dry Mg/hour)", fontsize = fs)
ax1.set_ylim(0, 5)
ax1.tick_params(axis = 'y', labelsize = fs)
ax1.tick_params(axis = 'x', labelsize = fs)

ax2 = ax1.twinx()
gdp = ax2.bar(xx + w, with_var, width = w, color = 'y', align = 'center')
ax2.set_ylabel("Reduction in Coef. Var. (%)", fontsize = fs)
ax2.set_ylim(0, 140)
ax2.tick_params(axis = "y", labelsize = fs)
plt.legend([pop, gdp], ['Av. Feed.', 'Reduction'], frameon = False, fontsize = fs, ncol = 2)
# plt.show()

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/feedvar_with_buffer.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
name_buffers = ['Fixed capacity', 'Optimized buffer size capacity']

without_cost = [41.71, 41.71]
without_time = [27.87, 27.87]

x = np.arange(2)
fig, ax1 = plt.subplots(1, 1, figsize = (fig1, fig2))
w = 0.3

plt.xticks(x + w / 2, name_buffers, rotation = 'horizontal')
pop = ax1.bar(x, without_cost, width = w, color = 'c', align = 'center')
ax1.set_ylabel("Cost ($/dry Mg)", fontsize = fs)
ax1.set_ylim(0, 60)
ax1.tick_params(axis = 'y', labelsize = fs)
ax1.tick_params(axis = 'x', labelsize = fs)

ax2 = ax1.twinx()
gdp = ax2.bar(x + w, without_time, width = w, color = 'm', align = 'center')
ax2.set_ylabel("Min. Time (hours)", fontsize = fs)
ax2.set_ylim(0, 45)
ax2.tick_params(axis = "y", labelsize = fs)
plt.legend([pop, gdp], ['Cost', 'Min. Time'], frameon = False, fontsize = fs, ncol = 2)

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/costtime_without.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

with_cost = [35.97, 37.15]
with_time = [21.57, 21.07]

xx = np.arange(2)
fig, ax1 = plt.subplots(1, 1, figsize = (fig1, fig2))
w = 0.3

plt.xticks(xx + w / 2, name_buffers, rotation = 'horizontal')
pop = ax1.bar(xx, with_cost, width = w, color = 'c', align = 'center')
ax1.set_ylabel("Cost ($/dry Mg)", fontsize = fs)
ax1.set_ylim(0, 60)
ax1.tick_params(axis = 'y', labelsize = fs)
ax1.tick_params(axis = 'x', labelsize = fs)

ax2 = ax1.twinx()
gdp = ax2.bar(xx + w, with_time, width = w, color = 'm', align = 'center')
ax2.set_ylabel("Min. Time (hours)", fontsize = fs)
ax2.set_ylim(0, 45)
ax2.tick_params(axis = "y", labelsize = fs)
plt.legend([pop, gdp], ['Cost', 'Min. Time'], frameon = False, fontsize = fs, ncol = 2)
# plt.show()

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/costtime_with.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Sensitivity analysis (with fractional milling case)

# %%
cap_with_fixed_met = [0.725, 0.047, 0.015, 2.056, 2.037]
cap_with_fixed_str = [0.496, 3.114, 0.009, 4.536, 4.536]
avfeed_fixed = [3.780, 3.483, 3.483, 3.564, 3.566] # [FK, I added this for revision]
cap_bins = [4.536, 4.536, 4.536, 4.536, 4.536]
# cap_bins_new = [9.07185, 9.07185]

plt.figure(figsize = (18, fig2))
N = len(cap_with_fixed_met)
ind = np.arange(N)
plt.ylim(0, 12)
plt.bar(ind, cap_with_fixed_met, bar_width, color = 'tomato', label = 'Metering Bin Max. Inv.')
plt.bar(ind + bar_width, cap_with_fixed_str, bar_width, color = 'lime', label = 'Storage Bin Max. Inv.')
plt.bar(ind + 2*bar_width, avfeed_fixed, bar_width, color = 'b', label = 'Av. Feed. (dry Mg/hour)') # [FK, I added this for revision]
plt.legend(frameon = False, fontsize = fs, ncol = 2)

for i, v in enumerate(avfeed_fixed): # [FK, I added this for revision]
    plt.text(i + .3, v + 0.1, str(v), fontsize = fs) # [FK, I added this for revision]

plt.ylabel("Dry Mg", fontsize = fs)
plt.tick_params(axis = 'y', labelsize = fs)
plt.tick_params(axis = 'x', labelsize = fs)

axes2 = plt.twinx()
axes2.plot(["Baseline", "40H,60L,100M", "40H,100M,60L", "60L,100M,40H", "100M,60L,40H"], 
           cap_bins, color = 'k', label = 'Capacity', linewidth = linew, linestyle = 'dashed')
axes2.set_ylim(0, 12)
axes2.legend(loc = 'upper left', frameon = False, fontsize = fs, ncol = 2)
axes2.tick_params(axis = "y", labelsize = fs)

plt.savefig(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/inventory_with_fixed.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
cap_with_flex_met = [0.725, 0.064, 0.015, 4.131, 4.073]
cap_with_flex_str = [0.609, 3.114, 0.002, 6.528, 6.565]
avfeed_flex = [3.780, 3.483, 3.483, 3.648, 3.645] # [FK, I added this for revision]
cap_bins = [4.536, 4.536, 4.536, 4.536, 4.536]
cap_bins_new = [9.07185, 9.07185, 9.07185, 9.07185, 9.07185]

plt.figure(figsize = (18, fig2))
N = len(cap_with_flex_met)
ind = np.arange(N)
plt.ylim(0, 12)
plt.bar(ind, cap_with_flex_met, bar_width, color = 'tomato', label = 'Metering Bin Max. Inv.')
plt.bar(ind + bar_width, cap_with_flex_str, bar_width, color = 'lime', label = 'Storage Bin Max. Inv.')
plt.bar(ind + 2*bar_width, avfeed_flex, bar_width, color = 'b', label = 'Av. Feed. (dry Mg/hour)') # [FK, I added this for revision]

for i, v in enumerate(avfeed_flex): # [FK, I added this for revision]
    plt.text(i + .3, v + 0.1, str(v), fontsize = fs) # [FK, I added this for revision]
    
plt.legend(frameon = False, fontsize = fs, ncol = 2)
plt.ylabel("Dry Mg", fontsize = fs)
plt.tick_params(axis = 'y', labelsize = fs)
plt.tick_params(axis = 'x', labelsize = fs)

axes2 = plt.twinx()
axes2.plot(["Baseline", "40H,60L,100M", "40H,100M,60L", "60L,100M,40H", "100M,60L,40H"], 
           cap_bins, color = 'k', label = 'Capacity', linewidth = linew, linestyle = 'dashed')
axes2.plot(["Baseline", "40H,60L,100M", "40H,100M,60L", "60L,100M,40H", "100M,60L,40H"], 
           cap_bins_new, color = 'k', label = 'New Capacity', linewidth = linew, linestyle = 'dotted', marker = 'o')
# axes2.plot(["40H,60L,100M", "40H,100M,60L", "60L,100M,40H", "Base case", "100M,60L,40H"], 
#            cap_bins_new, color = 'k', label = 'New Capacity', linewidth = linew, linestyle = 'dotted', marker = 'o')
axes2.set_ylim(0, 12)
axes2.legend(loc = 'upper left', frameon = False, fontsize = fs, ncol = 1) # [FK, I changed this from 2 to 1 for revision]
axes2.tick_params(axis = "y", labelsize = fs)

plt.savefig(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/inventory_with_flex.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
# afed_without_cap = [2.752, 2.752, 2.752, 2.752, 2.752, 2.752, 2.752] # Fixed, 0.1, 0.3, 0.5, 0.7, 0.9, 1
# var_without_cap = [0.143, 0.154, 0.149, 0.127, 0.127, 0.127, 0.163] # Fixed, 0.1, 0.3, 0.5, 0.7, 0.9, 1

# plt.figure(figsize = (18, fig2))
# plt.plot(afed_without_cap, color = 'y', label = 'Av. Feed.', linewidth = linew)
# plt.ylim(2.6, 4)
# plt.legend(loc = 'upper right', frameon = False, fontsize = fs)
# plt.ylabel('Av. Feed (dry tons/hour)', fontsize = fs)
# plt.tick_params(axis = 'y', labelsize = fs)
# plt.tick_params(axis = "x", labelsize = fs)

# axes2 = plt.twinx()
# axes2.plot(name_capanalysis, var_without_cap, color = 'b', label = 'Coef. Var.', linewidth = linew)
# axes2.set_ylim(0, 0.23)
# axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
# axes2.set_ylabel('Coef. Var.', fontsize = fs)
# axes2.tick_params(axis = "y", labelsize = fs)

# plt.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/afeedvar_without.pdf', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
# cost_without_cap = [41.71, 41.71, 41.71, 41.71, 41.71, 41.71, 41.71] # Fixed, 0.1, 0.3, 0.5, 0.7, 0.9, 1
# time_without_cap = [27.87, 27.87, 27.87, 27.87, 27.87, 27.87, 27.87] # Fixed, 0.1, 0.3, 0.5, 0.7, 0.9, 1

# plt.figure(figsize = (18, fig2))
# plt.plot(cost_without_cap, color = 'y', label = 'Cost', linewidth = linew)
# plt.ylim(35.5, 45)
# plt.legend(loc = 'upper right', frameon = False, fontsize = fs)
# plt.ylabel('Cost (\$/dry ton)', fontsize = fs)
# plt.tick_params(axis = 'y', labelsize = fs)
# plt.tick_params(axis = "x", labelsize = fs)

# axes2 = plt.twinx()
# axes2.plot(name_capanalysis, time_without_cap, color = 'b', label = 'Min. Time', linewidth = linew)
# axes2.set_ylim(21, 32)
# axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
# axes2.set_ylabel('Min. Time (hours)', fontsize = fs)
# axes2.tick_params(axis = "y", labelsize = fs)

# plt.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/costtime_without.pdf', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## With fractional milling

# %% [markdown]
# ### Main results

# %%
# name_capanalysis = ['Fixed capacity', '10% Exp.', '30% Exp.', '50% Exp.', '70% Exp.', '90% Exp.', '100% Exp.']
# afed_with_cap = [3.564, 3.575, 3.589, 3.603, 3.620, 3.640, 3.649] # Fixed, 0.1, 0.3, 0.5, 0.7, 0.9, 1
# var_with_cap = [0.096, 0.079, 0.045, 0.012, 0.000, 0.000, 0.000] # Fixed, 0.1, 0.3, 0.5, 0.7, 0.9, 1

# plt.figure(figsize = (18, fig2))
# plt.plot(afed_with_cap, color = 'y', label = 'Av. Feed.', linewidth = linew)
# plt.ylim(2.6, 4)
# plt.legend(loc = 'upper right', frameon = False, fontsize = fs)
# plt.ylabel('Av. Feed (dry tons/hour)', fontsize = fs)
# plt.tick_params(axis = 'y', labelsize = fs)
# plt.tick_params(axis = "x", labelsize = fs)

# axes2 = plt.twinx()
# axes2.plot(name_capanalysis, var_with_cap, color = 'b', label = 'Coef. Var.', linewidth = linew)
# axes2.set_ylim(0, 0.23)
# axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
# axes2.set_ylabel('Coef. Var.', fontsize = fs)
# axes2.tick_params(axis = "y", labelsize = fs)

# plt.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/afeedvar_with.pdf', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
# cost_with_cap = [35.97, 36.09, 36.40, 36.67, 36.88, 37.06, 37.15] # Fixed, 0.1, 0.3, 0.5, 0.7, 0.9, 1
# time_with_cap = [21.57, 21.50, 21.42, 21.33, 21.23, 21.12, 21.07] # Fixed, 0.1, 0.3, 0.5, 0.7, 0.9, 1

# plt.figure(figsize = (18, fig2))
# plt.plot(cost_with_cap, color = 'y', label = 'Cost', linewidth = linew)
# plt.ylim(35.5, 45)
# plt.legend(loc = 'upper right', frameon = False, fontsize = fs)
# plt.ylabel('Cost (\$/dry ton)', fontsize = fs)
# plt.tick_params(axis = 'y', labelsize = fs)
# plt.tick_params(axis = "x", labelsize = fs)

# axes2 = plt.twinx()
# axes2.plot(name_capanalysis, time_with_cap, color = 'b', label = 'Min. Time', linewidth = linew)
# axes2.set_ylim(21, 32)
# axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
# axes2.set_ylabel('Min. Time (hours)', fontsize = fs)
# axes2.tick_params(axis = "y", labelsize = fs)

# plt.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/costtime_with.pdf', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# # Cost and time

# %%
cost_bffpc_all = [34.71, 34.71, 34.70, 34.71, 35.58, 35.59]
time_bffpc_all = [20.80, 20.80, 20.80, 20.80, 21.33, 21.33]

x = np.arange(6)
fig, ax1 = plt.subplots(1, 1, figsize = (18, 6))
w = 0.3

plt.xticks(x + w / 2, ["Baseline", "R.p. 1", "R.p. 2", "R.p. 3", "R.p. 4", "R.p. 5"], rotation = 'horizontal')
pop = ax1.bar(x, cost_bffpc_all, width = w, color = 'c', align = 'center')
ax1.set_ylabel("Cost ($/dry Mg)", fontsize = fs)
ax1.set_ylim(0, 45)
ax1.tick_params(axis = 'y', labelsize = fs)
ax1.tick_params(axis = 'x', labelsize = fs)

ax2 = ax1.twinx()
gdp = ax2.bar(x + w, time_bffpc_all, width = w, color = 'm', align = 'center')
ax2.set_ylabel("Min. Time (hours)", fontsize = fs)
ax2.set_ylim(0, 30)
ax2.tick_params(axis = "y", labelsize = fs)
plt.legend([pop, gdp], ['Cost', 'Min. Time'], frameon = False, fontsize = fs, ncol = 2)

plt.savefig(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/cost_time_bffpc_all.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# plt.figure(figsize = (18, fig2))
# N = len(cost_bffpc_all)
# ind = np.arange(N)
# plt.ylim(0, 45)
# plt.bar(ind, cost_bffpc_all, bar_width, color = 'r', label = 'Cost')     
# plt.legend(loc = 'upper right', frameon = False, fontsize = fs)
# plt.ylabel("Cost ($/dry ton)", fontsize = fs)
# plt.tick_params(axis = 'y', labelsize = fs)
# plt.tick_params(axis = 'x', labelsize = fs)

# axes2 = plt.twinx()
# axes2.plot(name_bffpc, time_bffpc_all, color = 'b', label = 'Min. Time', linewidth = linew)
# axes2.set_ylim(0, 30)
# axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
# axes2.set_ylabel('Min. Time (hours)', fontsize = fs)
# axes2.tick_params(axis = "y", labelsize = fs)

# plt.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/cost_time_bffpc_all.pdf', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
cost_hpc_all = [33.94, 36.80, 36.80, 37.15, 37.17]
time_hpc_all = [20.33, 22.07, 22.07, 21.07, 21.08]

x = np.arange(5)
fig, ax1 = plt.subplots(1, 1, figsize = (18, 6))
w = 0.3

plt.xticks(x + w / 2, ["Baseline", "40H,60L,100M", "40H,100M,60L", "60L,100M,40H", "100M,60L,40H"], 
           rotation = 'horizontal')
pop = ax1.bar(x, cost_hpc_all, width = w, color = 'c', align = 'center') 
ax1.set_ylabel("Cost ($/dry Mg)", fontsize = fs)
ax1.set_ylim(0, 45)
ax1.tick_params(axis = 'y', labelsize = fs)
ax1.tick_params(axis = 'x', labelsize = fs)

ax2 = ax1.twinx()
gdp = ax2.bar(x + w, time_hpc_all, width = w, color = 'm', align = 'center')
ax2.set_ylabel("Min. Time (hours)", fontsize = fs)
ax2.set_ylim(0, 30)
ax2.tick_params(axis = "y", labelsize = fs)
plt.legend([pop, gdp], ['Cost', 'Min. Time'], frameon = False, fontsize = fs, ncol = 2)

plt.savefig(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/cost_time_hpc_all.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# plt.figure(figsize = (18, fig2))
# N = len(cost_hpc_all)
# ind = np.arange(N)
# plt.ylim(0, 45)
# plt.bar(ind, cost_hpc_all, bar_width, color = 'r', label = 'Cost')     
# plt.legend(loc = 'upper right', frameon = False, fontsize = fs)
# plt.ylabel("Cost ($/dry ton)", fontsize = fs)
# plt.tick_params(axis = 'y', labelsize = fs)
# plt.tick_params(axis = 'x', labelsize = fs)

# axes2 = plt.twinx()
# axes2.plot(name_hpc, time_hpc_all, color = 'b', label = 'Min. Time', linewidth = linew)
# axes2.set_ylim(0, 30)
# axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
# axes2.set_ylabel('Min. Time (hours)', fontsize = fs)
# axes2.tick_params(axis = "y", labelsize = fs)

# plt.savefig(
#     'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/cost_time_hpc_all.pdf', 
#             dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# # Comparison of modeling and experimental results

# %%
name_mod_exp = ['Model', 'Experiment']

hpc_time_actual = [5.60, 7.08]
bffpc_time_actual = [5.60, 7.23]

x = np.arange(2)
fig, ax1 = plt.subplots(1, 1, figsize = (fig1, fig2))
w = 0.3

plt.xticks(x + w / 2, name_mod_exp, rotation = 'horizontal')
pop = ax1.bar(x, hpc_time_actual, width = w, color = 'firebrick', align = 'center')
gdp = ax1.bar(x + w, bffpc_time_actual, width = w, color = 'forestgreen', align = 'center')
ax1.set_ylabel("Processing time (hours)", fontsize = fs)
ax1.set_ylim(0, 11)
ax1.tick_params(axis = 'y', labelsize = fs)
ax1.tick_params(axis = 'x', labelsize = fs)
plt.legend([pop, gdp], ['HPC', 'BFFPC'], frameon = False, fontsize = fs, ncol = 1, loc = 'upper left')

plt.savefig(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/actualtime.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

hpc_time_total = [5.60, 9.65]
bffpc_time_total = [5.60, 9.54]

xx = np.arange(2)
fig, ax1 = plt.subplots(1, 1, figsize = (fig1, fig2))
w = 0.3

plt.xticks(xx + w / 2, name_mod_exp, rotation = 'horizontal')
pop = ax1.bar(xx, hpc_time_total, width = w, color = 'firebrick', align = 'center')
gdp = ax1.bar(xx + w, bffpc_time_total, width = w, color = 'forestgreen', align = 'center')
ax1.set_ylabel("Processing time (hours)", fontsize = fs)
ax1.set_ylim(0, 11)
ax1.tick_params(axis = 'y', labelsize = fs)
ax1.tick_params(axis = 'x', labelsize = fs)
plt.legend([pop, gdp], ['HPC', 'BFFPC'], frameon = False, fontsize = fs, ncol = 1, loc = 'upper left')
# plt.show()

plt.savefig(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/totaltime.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)



reduction = [95.37, 69.76]

xx = np.arange(2)
fig, ax1 = plt.subplots(1, 1, figsize = (fig1, fig2))
w = 0.3

plt.xticks(xx, name_mod_exp, rotation = 'horizontal')
ax1.bar(xx, reduction, width = w, color = ['firebrick', 'forestgreen'], align = 'center')
ax1.set_ylabel("Reduction in Coef. Var. (%)", fontsize = fs)
ax1.set_ylim(0, 110)
ax1.tick_params(axis = 'y', labelsize = fs)
ax1.tick_params(axis = 'x', labelsize = fs)
# plt.show()

plt.savefig(
    '/Users/Kucuksayacigil/Dropbox/INL Postdoc/Documentation/Paper writing/Figures/reduction.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# # Do not use the followings!!!

# %%
cap_without_met = [0.252, 0.164] # First is fixed, second is flexible
cap_without_str = [1.192, 1.195] # First is fixed, second is flexible
cap_bins = [4.535, 4.535]
cap_bins_new = [9.07185, 9.07185]

plt.figure(figsize = (10, fig2))          
N = len(cap_without_met)  
ind = np.arange(N)
plt.ylim(0, 2)
plt.bar(ind, cap_without_met, bar_width, color = 'r', label = 'Metering Bin Max. Inv.')
plt.bar(ind + bar_width, cap_without_str, bar_width, color = 'y', label = 'Storage Bin Max. Inv.')     
plt.legend(frameon = False, fontsize = fs)
plt.ylabel("Dry tons", fontsize = fs)
plt.tick_params(axis = 'y', labelsize = fs)
plt.tick_params(axis = 'x', labelsize = fs)

name_capacity = ['Fixed capacity', 'Flexible capacity']
axes2 = plt.twinx()
# axes2.plot(name_capacity, cap_bins, color = 'k', label = 'Capacity', linewidth = linew)
# axes2.plot(name_capacity, cap_bins_new, color = 'green', label = 'New Capacity', linewidth = linew)
axes2.plot(name_capacity, cap_bins, color = 'k', linewidth = linew)
axes2.plot(name_capacity, cap_bins_new, color = 'green', linewidth = linew)
axes2.set_ylim(0, 2)
axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
axes2.tick_params(axis = "y", labelsize = fs)
# axes2.set_ylabel('Line plot')

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/inventory_without.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
cap_without_fixed_met = [3.093, 0.025, 3.093, 3.093]
cap_without_fixed_str = [4.536, 0.025, 4.536, 4.536]
cap_bins = [4.535, 4.535, 4.535, 4.535]
# cap_bins_new = [9.07185, 9.07185]

plt.figure(figsize = (18, fig2))
N = len(cap_without_fixed_met)
ind = np.arange(N)
plt.ylim(0, 12)
plt.bar(ind, cap_without_fixed_met, bar_width, color = 'r', label = 'Metering Bin Max. Inv.')
plt.bar(ind + bar_width, cap_without_fixed_str, bar_width, color = 'y', label = 'Storage Bin Max. Inv.')
plt.legend(frameon = False, fontsize = fs)
plt.ylabel("Dry tons", fontsize = fs)
plt.tick_params(axis = 'y', labelsize = fs)
plt.tick_params(axis = 'x', labelsize = fs)

axes2 = plt.twinx()
axes2.plot(name_hpc, cap_bins, color = 'k', label = 'Capacity', linewidth = linew)
axes2.set_ylim(0, 12)
axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
axes2.tick_params(axis = "y", labelsize = fs)

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/inventory_without_fixed.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
cap_without_flex_met = [3.093, 0.004, 3.093, 3.093]
cap_without_flex_str = [4.536, 0.009, 4.536, 4.536]
cap_bins = [4.535, 4.535, 4.535, 4.535]
cap_bins_new = [9.07185, 9.07185, 9.07185, 9.07185]

plt.figure(figsize = (18, fig2))
N = len(cap_without_flex_met)
ind = np.arange(N)
plt.ylim(0, 12)
plt.bar(ind, cap_without_flex_met, bar_width, color = 'r', label = 'Metering Bin Max. Inv.')
plt.bar(ind + bar_width, cap_without_flex_str, bar_width, color = 'y', label = 'Storage Bin Max. Inv.')
plt.legend(frameon = False, fontsize = fs)
plt.ylabel("Dry tons", fontsize = fs)
plt.tick_params(axis = 'y', labelsize = fs)
plt.tick_params(axis = 'x', labelsize = fs)

axes2 = plt.twinx()
axes2.plot(name_hpc, cap_bins, color = 'k', label = 'Capacity', linewidth = linew)
axes2.plot(name_hpc, cap_bins_new, color = 'green', label = 'New Capacity', linewidth = linew)
axes2.set_ylim(0, 12)
axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
axes2.tick_params(axis = "y", labelsize = fs)

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/inventory_without_flex.pdf', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)

# %%
cap_with_met = [0.725, 0.725] # First is fixed, second is flexible
cap_with_str = [0.496, 0.609] # First is fixed, second is flexible
cap_bins = [4.535, 4.535]
cap_bins_new = [9.07185, 9.07185]

plt.figure(figsize = (10, fig2))          
N = len(cap_with_met)  
ind = np.arange(N)
plt.ylim(0, 2)
plt.bar(ind, cap_with_met, bar_width, color = 'r', label = 'Metering Bin Max. Inv.')
plt.bar(ind + bar_width, cap_with_str, bar_width, color = 'y', label = 'Storage Bin Max. Inv.')     
plt.legend(frameon = False, fontsize = fs)
plt.ylabel("Dry tons", fontsize = fs)
plt.tick_params(axis = 'y', labelsize = fs)
plt.tick_params(axis = 'x', labelsize = fs)

axes2 = plt.twinx()
# axes2.plot(name_capacity, cap_bins, color = 'k', label = 'Old Capacity', linewidth = linew)
# axes2.plot(name_capacity, cap_bins_new, color = 'green', label = 'New Capacity', linewidth = linew)
axes2.plot(name_capacity, cap_bins, color = 'k', linewidth = linew)
axes2.plot(name_capacity, cap_bins_new, color = 'green', linewidth = linew)
axes2.set_ylim(0, 2)
axes2.legend(loc = 'upper left', frameon = False, fontsize = fs)
axes2.tick_params(axis = "y", labelsize = fs)
# axes2.set_ylabel('Line plot')

plt.savefig(
    'C:/Users/KUCUFN/Desktop/Fikri all files/Documentation/Paper writing/Figures/inventory_with.jpg', 
            dpi = dpi_qual, bbox_inches = 'tight', pad_inches = 0)
